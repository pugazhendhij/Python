# %% [markdown]
# 1.
#     a1 = [0, 0, 0, 1, 2, 3]   # extra space at beginning
#     a2 = [4, 5, 6]
#
#     final output = [1,2,3,4,5,6]

# %%
def merge_arr(a1,a2):

    write = 0
    # Step 1: shift non-zero elements to the front
    for i in range(len(a1)):
        if a1[i] != 0:
            a1[write] = a1[i] 
            write += 1

    i = len(a1) - len(a2) - 1
    j = len(a2) - 1
    k = len(a1) - 1


    while i >= 0 and j>= 0:
        if a1[i] > a2[j]:
            a1[k] = a1[i]
            i -= 1
        else:
            a1[k] = a2[j]
            j -= 1

        k -= 1

    while j >= 0:
        a1[k] = a2[j]
        j -= 1
        k -= 1

    return a1


print(merge_arr([1,2,3,0,0,0],[2,5,6]))
# Out:
# [1, 2, 2, 3, 5, 6]
