# %% [markdown]
# 66. Plus One
#
# You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading 0's.
#
# Increment the large integer by one and return the resulting array of digits.
#
#
#
# Example 1:
#
# Input: digits = [1,2,3]
# Output: [1,2,4]
# Explanation: The array represents the integer 123.
# Incrementing by one gives 123 + 1 = 124.
# Thus, the result should be [1,2,4].

# %%
def plusone(arr):
    n = len(arr)

    for i in range(n-1, -1, -1):
        if arr[i] < 9:
            arr[i] += 1
            return arr
        else:
            arr[i] = 0
    return [1] + arr
    


print(plusone([9,9,9]))
# Out:
# [1, 0, 0, 0]

# %% [markdown]
# # 🧠 Key Idea Before Execution
#
# * Start from the **last digit** (rightmost)
# * Handle **carry**, just like manual addition
# * Stop as soon as carry is resolved
#
# ---
#
# # 🧪 Example 1: `digits = [1, 2, 3]`
#
# ### Step 1: Length
#
# ```
# n = 3
# ```
#
# ---
#
# ### Step 2: Loop starts from last index
#
# ```
# i = 2
# digits[2] = 3
# ```
#
# ### Condition check
#
# ```
# 3 < 9  ✅
# ```
#
# ### Action
#
# ```
# digits[2] += 1 → 4
# ```
#
# ### Return immediately
#
# ```
# [1, 2, 4]
# ```
#
# ⛔ Loop stops here
#
# ---
#
# # 🧪 Example 2: `digits = [1, 2, 9]`
#
# ### Step 1
#
# ```
# n = 3
# ```
#
# ---
#
# ### Iteration 1
#
# ```
# i = 2
# digits[2] = 9
# ```
#
# ### Condition
#
# ```
# 9 < 9 ❌
# ```
#
# ### Action
#
# ```
# digits[2] = 0
# ```
#
# Carry moves left
#
# ---
#
# ### Iteration 2
#
# ```
# i = 1
# digits[1] = 2
# ```
#
# ### Condition
#
# ```
# 2 < 9 ✅
# ```
#
# ### Action
#
# ```
# digits[1] += 1 → 3
# ```
#
# ### Return
#
# ```
# [1, 3, 0]
# ```
#
# ---
#
# # 🧪 Example 3: `digits = [9, 9, 9]`
#
# ### Step 1
#
# ```
# n = 3
# ```
#
# ---
#
# ### Iteration 1
#
# ```
# i = 2
# digits[2] = 9
# ```
#
# Action:
#
# ```
# digits[2] = 0
# ```
#
# ---
#
# ### Iteration 2
#
# ```
# i = 1
# digits[1] = 9
# ```
#
# Action:
#
# ```
# digits[1] = 0
# ```
#
# ---
#
# ### Iteration 3
#
# ```
# i = 0
# digits[0] = 9
# ```
#
# Action:
#
# ```
# digits[0] = 0
# ```
#
# ---
#
# ### Loop ends (carry still exists)
#
# ### Final Step
#
# ```python
# return [1] + digits
# ```
#
# Result:
#
# ```
# [1, 0, 0, 0]
# ```
#
# ---
#
# # 🔁 What the Loop Really Means
#
# ```python
# for i in range(n - 1, -1, -1):
# ```
#
# Means:
#
# ```
# Start at last index
# Move left
# Stop at index 0
# ```
#
# ---
#
# # 🧠 Why `return` is Inside the Loop
#
# Once a digit `< 9` is found:
#
# * Carry is resolved
# * No need to check further digits
# * Early return improves performance
#
# ---
#
# # ⏱️ Complexity
#
# | Type  | Value    |
# | ----- | -------- |
# | Time  | **O(n)** |
# | Space | **O(1)** |
#
# ---
#
# # 🗣️ Interview Explanation (Use This)
#
# > “I iterate from the least significant digit, propagate the carry, and return early once the carry is handled.”
#
# ---
#
# # 📌 Summary
#
# ✔ Starts from right
# ✔ Handles carry correctly
# ✔ Efficient
# ✔ Interview-approved
#
# ---
#
# If you want next:
#
# * Visual diagram
# * Why `digits[i] = 0`
# * Similar carry-based problems
# * Edge cases checklist
#
# Just tell me 😊
