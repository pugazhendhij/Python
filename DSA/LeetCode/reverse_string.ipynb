# %% [markdown]
# 344. Reverse String
#
#
# Write a function that reverses a string. The input string is given as an array of characters s.
#
# You must do this by modifying the input array in-place with O(1) extra memory.
#
#
# Example 1:
#
# Input: s = ["h","e","l","l","o"]
# Output: ["o","l","l","e","h"]
# Example 2:
#
# Input: s = ["H","a","n","n","a","h"]
# Output: ["h","a","n","n","a","H"]

# %%
def reverseString(s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        left = 0
        right = len(s) - 1
        while left < right:
            s[left],s[right] = s[right],s[left]
            left += 1
            right -= 1
        
        return s
        
print(reverseString(["h","e","l","l","o"]))
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %% [markdown]
# ## 🧠 How This Works (Step-by-Step)
#
# Example:
# ```python
# s = ["h","e","l","l","o"]
# ```
#
# ### Initial pointers:
# ```
# left  → "h"
# right → "o"
# ```
#
# ### Swap:
# ```
# ["o","e","l","l","h"]
# ```
#
# Move pointers:
# ```
# left++ , right--
# ```
#
# Repeat until `left >= right`.
#
# ---
#
# ## ⏱ Complexity Analysis
#
# - **Time Complexity:** `O(n)`
# - **Space Complexity:** `O(1)` ✔️ (only variables used)
#
# ---
#
# ## 🧪 Example Walkthrough
#
# ### Input:
# ```python
# ["H","a","n","n","a","h"]
# ```
#
# ### Swaps:
# ```
# H ↔ h → ["h","a","n","n","a","H"]
# ```
#
# Pointers meet → stop.
#
# ---
#
# ## ❌ Common Wrong Approach (Don’t Use)
#
# ```python
# s = s[::-1]  # ❌ NOT in-place, uses extra memory
# ```
#
# Interviewers will ❌ reject this.
#
# ---
#
# ## 🎯 Interview Answer (How to Explain Verbally)
#
# > “I use a two-pointer approach. One pointer starts at the beginning, the other at the end. I swap the characters and move the pointers inward. This reverses the array in-place using O(1) space.”
#
# ---
#
# ## ⭐ Bonus: Pythonic but Still In-Place
#
# ```python
# class Solution(object):
#     def reverseString(self, s):
#         s.reverse()
# ```
#
# ⚠️ Works **only if interviewer allows built-in methods**.
# Safe choice → **two-pointer method**.
#
# ---
#
# If you want:
# - Recursion version
# - C++ / Java version
# - How to explain this in **1-minute interview answer**
#
# Just say the word 🙂
